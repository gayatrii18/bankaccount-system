# %%
class BankAccount :

    def __init__(self,user, admin, balance=0):
        self.user = user
        self.admin = admin
        self.balance = balance

    def deposite(self,user, amount):
        self.user = user
        self.balance += amount
        print(f"New credited amount is:{amount}. {self.user} has Available balance is: {self.balance}")

    def withdraw(self, user, amount):
        if(amount > 0):
            if(self.balance > amount):
                self.user = user
                self.balance -= amount
                print(f"{self.user} has withdraw {amount} rupees. Available balance is {self.balance}")
            else:
                print("Insufficient balance")
        else:
            print("Oops! Invalid amount")

    def check_balance(self, user ):
        print(f"{self.user} has available balance is {self.balance}")

Account1 = BankAccount(1, 1, 200)
Account1.deposite('Ramesh',2000)
Account1.withdraw('Ramesh',3000)
Account1.check_balance('Ramesh')
# Out:
# New credited amount is:2000. Ramesh has Available balance is: 2200
# Insufficient balance
# Ramesh has available balance is 2200

# %%
class BankAccount :

    def __init__(self,user, admin, balance=0):
        self.user = user
        self.admin = admin
        self.balance = balance

    def deposite(self,user, amount):
        self.user = user
        self.balance += amount
        print(f"New credited amount is:{amount}. {self.user} has Available balance is: {self.balance}")

    def withdraw(self, user, amount):
        if(amount > 0):
            if(self.balance > amount):
                self.user = user
                self.balance -= amount
                print(f"{self.user} has withdraw {amount} rupees. Available balance is {self.balance}")
            else:
                print("Insufficient balance")
        else:
            print("Oops! Invalid amount")

    def check_balance(self, user ):
        print(f"{self.user} has available balance is {self.balance}")

Account1 = BankAccount("Ramesh", 1, 200)

while True:
    print("\n Choose an operation: ")
    print("1. Deposite")
    print("2. Withdraw")
    print("3. Check_balance")
    print("4. exit")

    choice = int(input("Enter the choice(1-4): "))

    if choice == 1:
        amount = int(input("Enter the amount to deposite: "))
        Account1.deposite("Ramesh", amount)

    elif choice == 2:
        amount = int(input("Enter the amount to withdraw: "))
        Account1.withdraw("Ramesh", amount)

    elif choice == 3:
        Account1.check_balance("Ramesh")

    elif choice == 4:
        print("Exiting.....!Thank You")

    else:
        print("Invalide choice. Please try again")
